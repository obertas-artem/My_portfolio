# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Место для твоего комментария
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Привет! Спасибо большое за ревью, очень приятно, что сразу получилось хорошо выполнить проект) Ниже этого комментария я ничего не менял и комментарии не оставлял, вопросы напишу тут же:
#
# 1) Что лучше делать со строками в `income_type` с безработными, предпринимателями, студентами и в декрете? Просто не трогать или все таки удалять?
#
# 2) Я правильно понимаю, что пока цель проекта это отработка пройденных инструментов в спринте, то математические выводы не особо важны? Имеют ли место быть приколы, которые я делал с пропусками в в `total_income` с медианой по группам и в `days_employed`, где я вообще удалил выбросы, которые нашел и уже потом заполнял разными способами?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>И снова привет!
#
# 1) В данном случае это не особо важно, так как это учебно-тренировочный датасет. В реальной задаче стоит обратиться к коллеге или заказчику чтобы узнать важны ли эти данные
#
# 2) Это не обязательно, но круто, что ты это обнаружил и выполнил. Это уже более продвинутый подход к решению задачи, так что это определённо большой плюс)
#
# <br>Ты проделал большую работу! У тебя точные выводы с хорошей аргументацией. Здорово, что ты пишешь свои рассуждения и предположения - это помогает видеть ход твоей мысли. Отдельно хочу выделить аккуратность и структурированность твоей работы. Рад был поработать над проверкой твоего проекта! Желаю удачи в дальнейшем обучении! 😉
#
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски-в-total_income" data-toc-modified-id="Пропуски-в-total_income-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Пропуски в <code>total_income</code></a></span></li><li><span><a href="#Обработка-аномалий-и-заполнение-пропусков-в-df-и-days_emploed" data-toc-modified-id="Обработка-аномалий-и-заполнение-пропусков-в-df-и-days_emploed-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка аномалий и заполнение пропусков в <code>df</code> и <code>days_emploed</code></a></span><ul class="toc-item"><li><span><a href="#Обработка-children" data-toc-modified-id="Обработка-children-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Обработка <code>children</code></a></span></li><li><span><a href="#Обработка-dob_years" data-toc-modified-id="Обработка-dob_years-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Обработка <code>dob_years</code></a></span></li><li><span><a href="#Обработка-gender" data-toc-modified-id="Обработка-gender-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Обработка <code>gender</code></a></span></li><li><span><a href="#Обработка-days_employed" data-toc-modified-id="Обработка-days_employed-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Обработка <code>days_employed</code></a></span></li></ul></li><li><span><a href="#Замена-типа-данных-в-total_income" data-toc-modified-id="Замена-типа-данных-в-total_income-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Замена типа данных в <code>total_income</code></a></span></li><li><span><a href="#Обработка--на-дубликаты:" data-toc-modified-id="Обработка--на-дубликаты:-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка  на дубликаты:</a></span><ul class="toc-item"><li><span><a href="#Обработка-неявных-дубликатов" data-toc-modified-id="Обработка-неявных-дубликатов-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Обработка неявных дубликатов</a></span></li><li><span><a href="#Удаление-строк-дубликатов" data-toc-modified-id="Удаление-строк-дубликатов-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Удаление строк-дубликатов</a></span></li></ul></li><li><span><a href="#Создание-&quot;словарей&quot;" data-toc-modified-id="Создание-&quot;словарей&quot;-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Создание "словарей"</a></span></li><li><span><a href="#Создание-категории-total_income_category" data-toc-modified-id="Создание-категории-total_income_category-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Создание категории <code>total_income_category</code></a></span></li><li><span><a href="#Создание-категории-purpose_category" data-toc-modified-id="Создание-категории-purpose_category-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Создание категории <code>purpose_category</code></a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Между-количеством-детей-у-заемщика-и-возвратом-кредита-в-срок-есть-зависимость." data-toc-modified-id="Между-количеством-детей-у-заемщика-и-возвратом-кредита-в-срок-есть-зависимость.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Между количеством детей у заемщика и возвратом кредита в срок есть зависимость.</a></span></li><li><span><a href="#Между-семейным-положением-заемщика-и-возвратом-кредита-в-срок-есть-зависимость." data-toc-modified-id="Между-семейным-положением-заемщика-и-возвратом-кредита-в-срок-есть-зависимость.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Между семейным положением заемщика и возвратом кредита в срок есть зависимость.</a></span></li><li><span><a href="#Между-уровнем-дохода-заемщика-и-возвратом-кредита-в-срок-есть-зависимость." data-toc-modified-id="Между-уровнем-дохода-заемщика-и-возвратом-кредита-в-срок-есть-зависимость.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Между уровнем дохода заемщика и возвратом кредита в срок есть зависимость.</a></span></li><li><span><a href="#Разные-цели-кредита-влияют-на-его-возврат-в-срок." data-toc-modified-id="Разные-цели-кредита-влияют-на-его-возврат-в-срок.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Разные цели кредита влияют на его возврат в срок.</a></span></li></ul></li><li><span><a href="#Итоги-исследования" data-toc-modified-id="Итоги-исследования-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Итоги исследования</a></span></li></ul></div>

# %% [markdown]
# # Исследование надёжности заёмщиков

# %% [markdown]
# Заказчик - кредитный отдел банка. Банк предоставил данные - статистика о платежеспособности клиентов, на основании которых нужно выяснить, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку. Таким образом:
#
# **Цель исследования** - Выяснить, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок.
#
# Для удобства исследования выдвинем **гипотезы:**
#
# 1. Между количеством детей у заемщика и возвратом кредита в срок есть зависимость.(Есть ли зависимость между количеством детей и возвратом кредита в срок?)
# 2. Между семейным положением заемщика и возвратом кредита в срок есть зависимость.(Есть ли зависимость между семейным положением и возвратом кредита в срок?)
# 3. Между уровнем дохода заемщика и возвратом кредита в срок есть зависимость.(Есть ли зависимость между уровнем дохода и возвратом кредита в срок?)
# 4. Разные цели кредита влияют на его возврат в срок.(Как разные цели кредита влияют на его возврат в срок?)
#
# **Ход исследования**
#
# Данные, которые предоставил банк находятся в файле `data.csv`. Известно, что в данных есть пропущенные значения и аномалии, но насколько данные грязные неясно, поэтому первым этапом исследования будет обзор данных. Далее на этапе предобработки данных нужно будет исправить самые явные ошибки. Таким образом, исследование пройдет в три этапа:
#  1. Обзор данных.
#  2. Предобработка данных.
#  3. Проверка гипотез.

# %% [markdown]
# ## Обзор данных

# %%
import pandas as pd
import os
import numpy as np
pd.set_option('float_format', '{:f}'.format)

# %%
try:
    os.path.exists('/datasets/data.csv')
    df_raw = pd.read_csv('/datasets/data.csv')
except:
    df_raw = pd.read_csv('datasets/data.csv')
df = df_raw.copy()

# %%
#получаем случайные 10 строк таблицы df 
df.sample(10, random_state=150)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 3977          0  363122.181989         66   среднее             1
# 60            1   -2534.462390         48   среднее             1
# 5681          0            NaN         42   среднее             1
# 16871         0    -220.923972         50   среднее             1
# 16987         0  338538.066449         54   среднее             1
# 19746         0            NaN         57   среднее             1
# 17858         0  349331.304149         53   среднее             1
# 11871         0    -221.044147         54   среднее             1
# 20730         0   -3758.464824         56   среднее             1
# 15854         1    -340.850341         26    высшее             0
#
#                family_status  family_status_id gender income_type  debt  \
# 3977         женат / замужем                 0      M   пенсионер     0
# 60           женат / замужем                 0      M   сотрудник     0
# 5681         женат / замужем                 0      F   сотрудник     0
# 16871        женат / замужем                 0      M   сотрудник     0
# 16987       гражданский брак                 1      F   пенсионер     0
# 19746        женат / замужем                 0      F   компаньон     0
# 17858         вдовец / вдова                 2      F   пенсионер     0
# 11871        женат / замужем                 0      F   компаньон     0
# 20730        женат / замужем                 0      F   компаньон     0
# 15854  Не женат / не замужем                 4      M   компаньон     0
#
#        total_income                   purpose
# 3977   52469.440120      покупка недвижимости
# 60    129902.283735     заняться образованием
# 5681            NaN                автомобиль
# 16871  86890.747766             покупка жилья
# 16987  66703.634771                   свадьба
# 19746           NaN     получение образования
# 17858 116136.260674                     жилье
# 11871 148638.570112  операции с недвижимостью
# 20730 116081.565706               образование
# 15854 238277.990736  операции с недвижимостью

# %%
#получение общей информации о данных в таблице df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# В таблице 12 столбцов, в таблице присутствует два столбца с типом данных - `float64`, пять - `int64` и еще пять - `object`.
# Согласно документации к данным:
# * `children` — количество детей в семье
# * `days_employed` — общий трудовой стаж в днях
# * `dob_years` — возраст клиента в годах
# * `education` — уровень образования клиента
# * `education_id` — идентификатор уровня образования
# * `family_status` — семейное положение
# * `family_status_id` — идентификатор семейного положения
# * `gender` — пол клиента
# * `income_type` — тип занятости
# * `debt` — имел ли задолженность по возврату кредитов
# * `total_income` — ежемесячный доход
# * `purpose` — цель получения кредита
#
# В столбцах `days_employed` и `total_income` есть пропуски, узнаем сколько:

# %%
df.isna().sum()/len(df)
# Out:
# children           0.000000
# days_employed      0.100999
# dob_years          0.000000
# education          0.000000
# education_id       0.000000
# family_status      0.000000
# family_status_id   0.000000
# gender             0.000000
# income_type        0.000000
# debt               0.000000
# total_income       0.100999
# purpose            0.000000
# dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ещё можно посмотреть долю пропущенных значений среди всех данных следующим способом
#
#     df.isna().mean()
# </div>

# %% [markdown]
# В столбце `days_employed` 10.1% данных отсутствует
#
# В столбце `total_income` 10.1% данных отсутствует

# %%
#Проверим, что строки с пропусками в двух столбцах совпадают:
df.loc[(df['days_employed'].isna()) & (df['total_income'].isna())].count()
# Out:
# children            2174
# days_employed          0
# dob_years           2174
# education           2174
# education_id        2174
# family_status       2174
# family_status_id    2174
# gender              2174
# income_type         2174
# debt                2174
# total_income           0
# purpose             2174
# dtype: int64

# %%
#Возможно между пропусками есть какая-то связь, напишем функцию:
try:
    def nan_reason(nan_column,reason_column):
        a = df.loc[df[nan_column].isnull()][reason_column].value_counts()
        return(a)
except:
    print('Что-то пошло не так')

# %%
#Возможно, есть связь с типо занятости:
nan_reason('days_employed', 'income_type')
# Out:
# сотрудник          1105
# компаньон           508
# пенсионер           413
# госслужащий         147
# предприниматель       1
# Name: income_type, dtype: int64

# %%
#Возможно, есть связь с задолжностями:
nan_reason('days_employed', 'debt')
# Out:
# 0    2004
# 1     170
# Name: debt, dtype: int64

# %%
#Возможно, есть связь с уровнем образования: 
nan_reason('days_employed', 'education')
# Out:
# среднее                1408
# высшее                  496
# СРЕДНЕЕ                  67
# Среднее                  65
# неоконченное высшее      55
# Высшее                   25
# ВЫСШЕЕ                   23
# начальное                19
# Неоконченное высшее       7
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       7
# НАЧАЛЬНОЕ                 1
# Начальное                 1
# Name: education, dtype: int64

# %%
#Связь с целью кредита:
nan_reason('days_employed', 'purpose')
# Out:
# на проведение свадьбы                     92
# сыграть свадьбу                           81
# свадьба                                   76
# строительство собственной недвижимости    75
# операции с жильем                         74
# покупка недвижимости                      72
# покупка жилья для семьи                   71
# операции со своей недвижимостью           71
# операции с коммерческой недвижимостью     70
# ремонт жилью                              70
# покупка коммерческой недвижимости         67
# покупка жилья для сдачи                   65
# недвижимость                              62
# покупка жилой недвижимости                61
# операции с недвижимостью                  61
# жилье                                     60
# строительство недвижимости                59
# автомобили                                57
# заняться высшим образованием              56
# заняться образованием                     55
# сделка с подержанным автомобилем          54
# на покупку своего автомобиля              53
# свой автомобиль                           52
# покупка жилья                             52
# получение дополнительного образования     51
# получение образования                     50
# дополнительное образование                48
# профильное образование                    47
# сделка с автомобилем                      46
# строительство жилой недвижимости          46
# покупка своего жилья                      46
# приобретение автомобиля                   43
# на покупку подержанного автомобиля        42
# образование                               42
# автомобиль                                41
# высшее образование                        40
# получение высшего образования             36
# на покупку автомобиля                     30
# Name: purpose, dtype: int64

# %%
#Связь с количеством детей:
nan_reason('days_employed','children')
# Out:
#  0     1439
#  1      475
#  2      204
#  3       36
#  20       9
#  4        7
# -1        3
#  5        1
# Name: children, dtype: int64

# %%
#Связь с возрастом:
nan_reason('days_employed', 'dob_years')
# Out:
# 34    69
# 40    66
# 31    65
# 42    65
# 35    64
# 36    63
# 47    59
# 41    59
# 30    58
# 28    57
# 57    56
# 58    56
# 54    55
# 38    54
# 56    54
# 37    53
# 52    53
# 39    51
# 33    51
# 50    51
# 51    50
# 45    50
# 49    50
# 29    50
# 43    50
# 46    48
# 55    48
# 48    46
# 53    44
# 44    44
# 60    39
# 61    38
# 62    38
# 64    37
# 32    37
# 27    36
# 23    36
# 26    35
# 59    34
# 63    29
# 25    23
# 24    21
# 66    20
# 65    20
# 21    18
# 22    17
# 67    16
# 0     10
# 68     9
# 69     5
# 20     5
# 71     5
# 70     3
# 72     2
# 19     1
# 73     1
# Name: dob_years, dtype: int64

# %%
#Связь с полом:
nan_reason('days_employed','gender')
# Out:
# F    1484
# M     690
# Name: gender, dtype: int64

# %% [markdown]
# Установить связь пропусков в `total_income` и `days_employed` c другими столбцами не удалось. Единственное, что удалось выяснить, что строки с пропусками в `total_income` совпадают с пропусками в `days_employed`.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отлично!
# <br>Во время первичного анализа данных, может помочь метод describe(). Он покажет разброс значений, максимум, минимум, среднее и медиану.
# </div>

# %% [markdown]
#  ## Предобработка данных

# %% [markdown]
# ### Пропуски в `total_income`

# %% [markdown]
# В таблице есть два столбца с пропущенными значениями: `days_employed` и `total_income`, пропущенные значения заполнены `NaN`, тип данных `float`. Так как установить связь в пропущенных значениях с другими столбцами не удалось, а единственное, что известно, это, что строки с пропусками в `total_income` совпадают с пропусками в `days_employed`, будем считать, что пропуски не случайные, возможно, заемщики не захотели раскрывать свои доходы. Процентное соотношение данных к таблице в этих стобцах равно `10.1%`. Заполнять будем медианой, так как медиана в отличии от среднего устойчивее к выбросам в данных. Сначала заполним `total_income`, но попробуем предварительно посчитать медиану `total_income` по каждому `income_type`:

# %%
#Посмотрим какая медиана по `total_income` до преобразований:
df['total_income'].median()
# Out:
# 145017.93753253992

# %%
#Медиана по каждому 'income_type':
median_by_income_type = df.groupby('income_type')['total_income'].median()
median_by_income_type
# Out:
# income_type
# безработный       131339.751676
# в декрете          53829.130729
# госслужащий       150447.935283
# компаньон         172357.950966
# пенсионер         118514.486412
# предприниматель   499163.144947
# сотрудник         142594.396847
# студент            98201.625314
# Name: total_income, dtype: float64

# %%
df['income_type'].value_counts()
# Out:
# сотрудник          11119
# компаньон           5085
# пенсионер           3856
# госслужащий         1459
# безработный            2
# предприниматель        2
# студент                1
# в декрете              1
# Name: income_type, dtype: int64

# %% [markdown]
# Мы видим, что все медианные значения по `income_type` выглядят реальными и их можно объяснить. Также видим, что из всего списка заемщиков всего 2 предринимателя, 2 безработных, 1 студент и 1 в декрете, так как на цели исследования это никак не влияет, не будет обращать на это внимание.
#
# Приступаем к заполнению `total_income`:

# %%
#Для проверки создадим `series` с пропусками в столбце 'total_income' в переменную `total_income_nan_check`:
total_income_nan_check = df.loc[df['total_income'].isna()]['total_income']
total_income_nan_check
# Out:
# 12      NaN
# 26      NaN
# 29      NaN
# 41      NaN
# 55      NaN
#          ..
# 21489   NaN
# 21495   NaN
# 21497   NaN
# 21502   NaN
# 21510   NaN
# Name: total_income, Length: 2174, dtype: float64

# %%
#Заполняет `total_income`:
df['total_income'] = df['total_income'].fillna(df.groupby('income_type')['total_income'].transform('median'))

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>То что нужно! Это отличный способ для замены пропусков в данном случае.
# </div>

# %%
#Проверяем, заполнились ли пропуски:
df.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income           0
# purpose                0
# dtype: int64

# %%
#Посмотрим, как заполнились пропуски:
qwer = []
for ind in total_income_nan_check.index:
    qwer.append(df.loc[ind])
qwer
#красиво не получилось вывести
# Out:
# [children                           0
#  days_employed                    NaN
#  dob_years                         65
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                пенсионер
#  debt                               0
#  total_income           118514.486412
#  purpose              сыграть свадьбу
#  Name: 12, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        41
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            M
#  income_type             госслужащий
#  debt                              0
#  total_income          150447.935283
#  purpose                 образование
#  Name: 26, dtype: object,
#  children                                           0
#  days_employed                                    NaN
#  dob_years                                         63
#  education                                    среднее
#  education_id                                       1
#  family_status                  Не женат / не замужем
#  family_status_id                                   4
#  gender                                             F
#  income_type                                пенсионер
#  debt                                               0
#  total_income                           118514.486412
#  purpose             строительство жилой недвижимости
#  Name: 29, dtype: object,
#  children                                           0
#  days_employed                                    NaN
#  dob_years                                         50
#  education                                    среднее
#  education_id                                       1
#  family_status                        женат / замужем
#  family_status_id                                   0
#  gender                                             F
#  income_type                              госслужащий
#  debt                                               0
#  total_income                           150447.935283
#  purpose             сделка с подержанным автомобилем
#  Name: 41, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         54
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                пенсионер
#  debt                               1
#  total_income           118514.486412
#  purpose              сыграть свадьбу
#  Name: 55, dtype: object,
#  children                                                0
#  days_employed                                         NaN
#  dob_years                                              21
#  education                                         среднее
#  education_id                                            1
#  family_status                       Не женат / не замужем
#  family_status_id                                        4
#  gender                                                  M
#  income_type                                     компаньон
#  debt                                                    0
#  total_income                                172357.950966
#  purpose             операции с коммерческой недвижимостью
#  Name: 65, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                52
#  education                            высшее
#  education_id                              0
#  family_status               женат / замужем
#  family_status_id                          0
#  gender                                    F
#  income_type                       пенсионер
#  debt                                      0
#  total_income                  118514.486412
#  purpose             покупка жилья для семьи
#  Name: 67, dtype: object,
#  children                                                1
#  days_employed                                         NaN
#  dob_years                                              32
#  education                                          высшее
#  education_id                                            0
#  family_status                             женат / замужем
#  family_status_id                                        0
#  gender                                                  M
#  income_type                                   госслужащий
#  debt                                                    0
#  total_income                                150447.935283
#  purpose             операции с коммерческой недвижимостью
#  Name: 72, dtype: object,
#  children                          2
#  days_employed                   NaN
#  dob_years                        50
#  education                    высшее
#  education_id                      0
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               сотрудник
#  debt                              0
#  total_income          142594.396847
#  purpose                       жилье
#  Name: 82, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        52
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            M
#  income_type               сотрудник
#  debt                              0
#  total_income          142594.396847
#  purpose                       жилье
#  Name: 83, dtype: object,
#  children                            2
#  days_employed                     NaN
#  dob_years                          35
#  education                      высшее
#  education_id                        0
#  family_status         женат / замужем
#  family_status_id                    0
#  gender                              F
#  income_type                 сотрудник
#  debt                                0
#  total_income            142594.396847
#  purpose             операции с жильем
#  Name: 90, dtype: object,
#  children                                1
#  days_employed                         NaN
#  dob_years                              34
#  education                          высшее
#  education_id                            0
#  family_status            гражданский брак
#  family_status_id                        1
#  gender                                  F
#  income_type                     компаньон
#  debt                                    0
#  total_income                172357.950966
#  purpose             на проведение свадьбы
#  Name: 94, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   44
#  education                              СРЕДНЕЕ
#  education_id                                 1
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       F
#  income_type                          сотрудник
#  debt                                         0
#  total_income                     142594.396847
#  purpose             покупка жилой недвижимости
#  Name: 96, dtype: object,
#  children                                 0
#  days_employed                          NaN
#  dob_years                               47
#  education                           высшее
#  education_id                             0
#  family_status              женат / замужем
#  family_status_id                         0
#  gender                                   F
#  income_type                      сотрудник
#  debt                                     0
#  total_income                 142594.396847
#  purpose             профильное образование
#  Name: 97, dtype: object,
#  children                             0
#  days_employed                      NaN
#  dob_years                           46
#  education                      среднее
#  education_id                         1
#  family_status          женат / замужем
#  family_status_id                     0
#  gender                               F
#  income_type                  сотрудник
#  debt                                 0
#  total_income             142594.396847
#  purpose             высшее образование
#  Name: 120, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        29
#  education                    высшее
#  education_id                      0
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               компаньон
#  debt                              0
#  total_income          172357.950966
#  purpose                  автомобиль
#  Name: 121, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        27
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            M
#  income_type               компаньон
#  debt                              0
#  total_income          172357.950966
#  purpose                       жилье
#  Name: 135, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         39
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                сотрудник
#  debt                               0
#  total_income           142594.396847
#  purpose                      свадьба
#  Name: 141, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   62
#  education                              среднее
#  education_id                                 1
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       M
#  income_type                          пенсионер
#  debt                                         0
#  total_income                     118514.486412
#  purpose             строительство недвижимости
#  Name: 145, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        55
#  education                    высшее
#  education_id                      0
#  family_status        вдовец / вдова
#  family_status_id                  2
#  gender                            F
#  income_type               компаньон
#  debt                              0
#  total_income          172357.950966
#  purpose             свой автомобиль
#  Name: 174, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                26
#  education                           среднее
#  education_id                              1
#  family_status              гражданский брак
#  family_status_id                          1
#  gender                                    F
#  income_type                       компаньон
#  debt                                      1
#  total_income                  172357.950966
#  purpose             покупка жилья для семьи
#  Name: 181, dtype: object,
#  children                                1
#  days_employed                         NaN
#  dob_years                              30
#  education                         среднее
#  education_id                            1
#  family_status       Не женат / не замужем
#  family_status_id                        4
#  gender                                  F
#  income_type                     сотрудник
#  debt                                    0
#  total_income                142594.396847
#  purpose                   свой автомобиль
#  Name: 189, dtype: object,
#  children                                             1
#  days_employed                                      NaN
#  dob_years                                           31
#  education                                       высшее
#  education_id                                         0
#  family_status                          женат / замужем
#  family_status_id                                     0
#  gender                                               F
#  income_type                                  сотрудник
#  debt                                                 0
#  total_income                             142594.396847
#  purpose             на покупку подержанного автомобиля
#  Name: 205, dtype: object,
#  children                              1
#  days_employed                       NaN
#  dob_years                            23
#  education           неоконченное высшее
#  education_id                          2
#  family_status          гражданский брак
#  family_status_id                      1
#  gender                                F
#  income_type                   компаньон
#  debt                                  0
#  total_income              172357.950966
#  purpose                 сыграть свадьбу
#  Name: 220, dtype: object,
#  children                                                 0
#  days_employed                                          NaN
#  dob_years                                               47
#  education                                          среднее
#  education_id                                             1
#  family_status                              женат / замужем
#  family_status_id                                         0
#  gender                                                   M
#  income_type                                      сотрудник
#  debt                                                     0
#  total_income                                 142594.396847
#  purpose             строительство собственной недвижимости
#  Name: 241, dtype: object,
#  children                               0
#  days_employed                        NaN
#  dob_years                             58
#  education                        среднее
#  education_id                           1
#  family_status            женат / замужем
#  family_status_id                       0
#  gender                                 F
#  income_type                  госслужащий
#  debt                                   0
#  total_income               150447.935283
#  purpose             покупка своего жилья
#  Name: 242, dtype: object,
#  children                                       1
#  days_employed                                NaN
#  dob_years                                     60
#  education                                 высшее
#  education_id                                   0
#  family_status                    женат / замужем
#  family_status_id                               0
#  gender                                         F
#  income_type                            пенсионер
#  debt                                           1
#  total_income                       118514.486412
#  purpose             заняться высшим образованием
#  Name: 247, dtype: object,
#  children                                           0
#  days_employed                                    NaN
#  dob_years                                         54
#  education                                     высшее
#  education_id                                       0
#  family_status                        женат / замужем
#  family_status_id                                   0
#  gender                                             F
#  income_type                                сотрудник
#  debt                                               0
#  total_income                           142594.396847
#  purpose             сделка с подержанным автомобилем
#  Name: 250, dtype: object,
#  children                       2
#  days_employed                NaN
#  dob_years                     40
#  education                среднее
#  education_id                   1
#  family_status          в разводе
#  family_status_id               3
#  gender                         F
#  income_type            сотрудник
#  debt                           0
#  total_income       142594.396847
#  purpose             недвижимость
#  Name: 264, dtype: object,
#  children                           1
#  days_employed                    NaN
#  dob_years                         23
#  education                    Среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                сотрудник
#  debt                               1
#  total_income           142594.396847
#  purpose                   автомобиль
#  Name: 278, dtype: object,
#  children                                          0
#  days_employed                                   NaN
#  dob_years                                        44
#  education                                   Среднее
#  education_id                                      1
#  family_status                      гражданский брак
#  family_status_id                                  1
#  gender                                            F
#  income_type                               сотрудник
#  debt                                              0
#  total_income                          142594.396847
#  purpose             операции со своей недвижимостью
#  Name: 279, dtype: object,
#  children                            0
#  days_employed                     NaN
#  dob_years                          66
#  education                     среднее
#  education_id                        1
#  family_status         женат / замужем
#  family_status_id                    0
#  gender                              F
#  income_type                 пенсионер
#  debt                                0
#  total_income            118514.486412
#  purpose             операции с жильем
#  Name: 280, dtype: object,
#  children                                  1
#  days_employed                           NaN
#  dob_years                                33
#  education                           среднее
#  education_id                              1
#  family_status              гражданский брак
#  family_status_id                          1
#  gender                                    M
#  income_type                       сотрудник
#  debt                                      1
#  total_income                  142594.396847
#  purpose             покупка жилья для сдачи
#  Name: 312, dtype: object,
#  children                                0
#  days_employed                         NaN
#  dob_years                              21
#  education                          высшее
#  education_id                            0
#  family_status       Не женат / не замужем
#  family_status_id                        4
#  gender                                  M
#  income_type                     сотрудник
#  debt                                    0
#  total_income                142594.396847
#  purpose              сделка с автомобилем
#  Name: 317, dtype: object,
#  children                                             0
#  days_employed                                      NaN
#  dob_years                                           63
#  education                                      среднее
#  education_id                                         1
#  family_status                           вдовец / вдова
#  family_status_id                                     2
#  gender                                               F
#  income_type                                  сотрудник
#  debt                                                 0
#  total_income                             142594.396847
#  purpose             на покупку подержанного автомобиля
#  Name: 320, dtype: object,
#  children                                1
#  days_employed                         NaN
#  dob_years                              34
#  education                          высшее
#  education_id                            0
#  family_status            гражданский брак
#  family_status_id                        1
#  gender                                  M
#  income_type                     компаньон
#  debt                                    0
#  total_income                172357.950966
#  purpose             на проведение свадьбы
#  Name: 321, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         56
#  education                    СРЕДНЕЕ
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                пенсионер
#  debt                               1
#  total_income           118514.486412
#  purpose              сыграть свадьбу
#  Name: 322, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                69
#  education                           среднее
#  education_id                              1
#  family_status                вдовец / вдова
#  family_status_id                          2
#  gender                                    F
#  income_type                       сотрудник
#  debt                                      0
#  total_income                  142594.396847
#  purpose             приобретение автомобиля
#  Name: 328, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                27
#  education                           среднее
#  education_id                              1
#  family_status               женат / замужем
#  family_status_id                          0
#  gender                                    M
#  income_type                       компаньон
#  debt                                      0
#  total_income                  172357.950966
#  purpose             покупка жилья для сдачи
#  Name: 360, dtype: object,
#  children                         0
#  days_employed                  NaN
#  dob_years                       59
#  education                  среднее
#  education_id                     1
#  family_status       вдовец / вдова
#  family_status_id                 2
#  gender                           F
#  income_type              пенсионер
#  debt                             0
#  total_income         118514.486412
#  purpose                      жилье
#  Name: 361, dtype: object,
#  children                                       0
#  days_employed                                NaN
#  dob_years                                     57
#  education                                среднее
#  education_id                                   1
#  family_status                   гражданский брак
#  family_status_id                               1
#  gender                                         F
#  income_type                            компаньон
#  debt                                           0
#  total_income                       172357.950966
#  purpose             заняться высшим образованием
#  Name: 364, dtype: object,
#  children                                        0
#  days_employed                                 NaN
#  dob_years                                      23
#  education                     Неоконченное высшее
#  education_id                                    2
#  family_status               Не женат / не замужем
#  family_status_id                                4
#  gender                                          M
#  income_type                             сотрудник
#  debt                                            0
#  total_income                        142594.396847
#  purpose             получение высшего образования
#  Name: 376, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         55
#  education                     высшее
#  education_id                       0
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                компаньон
#  debt                               0
#  total_income           172357.950966
#  purpose              сыграть свадьбу
#  Name: 383, dtype: object,
#  children                                     1
#  days_employed                              NaN
#  dob_years                                   31
#  education                              СРЕДНЕЕ
#  education_id                                 1
#  family_status                        в разводе
#  family_status_id                             3
#  gender                                       M
#  income_type                        госслужащий
#  debt                                         0
#  total_income                     150447.935283
#  purpose             дополнительное образование
#  Name: 389, dtype: object,
#  children                         0
#  days_employed                  NaN
#  dob_years                       57
#  education                   высшее
#  education_id                     0
#  family_status       вдовец / вдова
#  family_status_id                 2
#  gender                           F
#  income_type              пенсионер
#  debt                             0
#  total_income         118514.486412
#  purpose                      жилье
#  Name: 415, dtype: object,
#  children                                 0
#  days_employed                          NaN
#  dob_years                               58
#  education                          среднее
#  education_id                             1
#  family_status             гражданский брак
#  family_status_id                         1
#  gender                                   F
#  income_type                      пенсионер
#  debt                                     0
#  total_income                 118514.486412
#  purpose             профильное образование
#  Name: 416, dtype: object,
#  children                                 0
#  days_employed                          NaN
#  dob_years                               45
#  education                          среднее
#  education_id                             1
#  family_status              женат / замужем
#  family_status_id                         0
#  gender                                   F
#  income_type                      сотрудник
#  debt                                     0
#  total_income                 142594.396847
#  purpose             профильное образование
#  Name: 421, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        53
#  education                   среднее
#  education_id                      1
#  family_status        вдовец / вдова
#  family_status_id                  2
#  gender                            F
#  income_type               сотрудник
#  debt                              1
#  total_income          142594.396847
#  purpose             свой автомобиль
#  Name: 444, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         48
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                компаньон
#  debt                               0
#  total_income           172357.950966
#  purpose                      свадьба
#  Name: 458, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   56
#  education                              среднее
#  education_id                                 1
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       F
#  income_type                          пенсионер
#  debt                                         0
#  total_income                     118514.486412
#  purpose             дополнительное образование
#  Name: 466, dtype: object,
#  children                                1
#  days_employed                         NaN
#  dob_years                              29
#  education                         среднее
#  education_id                            1
#  family_status             женат / замужем
#  family_status_id                        0
#  gender                                  F
#  income_type                     компаньон
#  debt                                    0
#  total_income                172357.950966
#  purpose             на покупку автомобиля
#  Name: 490, dtype: object,
#  children                                0
#  days_employed                         NaN
#  dob_years                              54
#  education                          высшее
#  education_id                            0
#  family_status       Не женат / не замужем
#  family_status_id                        4
#  gender                                  M
#  income_type                     сотрудник
#  debt                                    0
#  total_income                142594.396847
#  purpose              покупка недвижимости
#  Name: 499, dtype: object,
#  children                           1
#  days_employed                    NaN
#  dob_years                         30
#  education                     высшее
#  education_id                       0
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                сотрудник
#  debt                               0
#  total_income           142594.396847
#  purpose              сыграть свадьбу
#  Name: 503, dtype: object,
#  children                          1
#  days_employed                   NaN
#  dob_years                        51
#  education                   СРЕДНЕЕ
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               компаньон
#  debt                              0
#  total_income          172357.950966
#  purpose                  автомобили
#  Name: 515, dtype: object,
#  children                                            0
#  days_employed                                     NaN
#  dob_years                                          29
#  education                                      высшее
#  education_id                                        0
#  family_status                   Не женат / не замужем
#  family_status_id                                    4
#  gender                                              M
#  income_type                                 компаньон
#  debt                                                0
#  total_income                            172357.950966
#  purpose             покупка коммерческой недвижимости
#  Name: 518, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         35
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                сотрудник
#  debt                               0
#  total_income           142594.396847
#  purpose              сыграть свадьбу
#  Name: 520, dtype: object,
#  children                                           0
#  days_employed                                    NaN
#  dob_years                                         57
#  education                                    среднее
#  education_id                                       1
#  family_status                        женат / замужем
#  family_status_id                                   0
#  gender                                             F
#  income_type                                сотрудник
#  debt                                               0
#  total_income                           142594.396847
#  purpose             сделка с подержанным автомобилем
#  Name: 541, dtype: object,
#  children                               0
#  days_employed                        NaN
#  dob_years                             60
#  education                        среднее
#  education_id                           1
#  family_status            женат / замужем
#  family_status_id                       0
#  gender                                 M
#  income_type                    сотрудник
#  debt                                   0
#  total_income               142594.396847
#  purpose             покупка недвижимости
#  Name: 554, dtype: object,
#  children                                0
#  days_employed                         NaN
#  dob_years                              52
#  education                         среднее
#  education_id                            1
#  family_status            гражданский брак
#  family_status_id                        1
#  gender                                  F
#  income_type                   госслужащий
#  debt                                    0
#  total_income                150447.935283
#  purpose             на проведение свадьбы
#  Name: 573, dtype: object,
#  children                           1
#  days_employed                    NaN
#  dob_years                         37
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                компаньон
#  debt                               1
#  total_income           172357.950966
#  purpose                      свадьба
#  Name: 619, dtype: object,
#  children                           1
#  days_employed                    NaN
#  dob_years                         34
#  education                     высшее
#  education_id                       0
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                сотрудник
#  debt                               0
#  total_income           142594.396847
#  purpose              сыграть свадьбу
#  Name: 627, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        52
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               сотрудник
#  debt                              0
#  total_income          142594.396847
#  purpose                недвижимость
#  Name: 645, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   44
#  education                              среднее
#  education_id                                 1
#  family_status                 гражданский брак
#  family_status_id                             1
#  gender                                       F
#  income_type                          сотрудник
#  debt                                         1
#  total_income                     142594.396847
#  purpose             покупка жилой недвижимости
#  Name: 646, dtype: object,
#  children                               0
#  days_employed                        NaN
#  dob_years                             45
#  education                        среднее
#  education_id                           1
#  family_status            женат / замужем
#  family_status_id                       0
#  gender                                 F
#  income_type                    компаньон
#  debt                                   0
#  total_income               172357.950966
#  purpose             покупка недвижимости
#  Name: 649, dtype: object,
#  children                                                1
#  days_employed                                         NaN
#  dob_years                                              26
#  education                                         среднее
#  education_id                                            1
#  family_status                            гражданский брак
#  family_status_id                                        1
#  gender                                                  F
#  income_type                                     компаньон
#  debt                                                    0
#  total_income                                172357.950966
#  purpose             операции с коммерческой недвижимостью
#  Name: 651, dtype: object,
#  children                                             0
#  days_employed                                      NaN
#  dob_years                                           32
#  education                                      среднее
#  education_id                                         1
#  family_status                    Не женат / не замужем
#  family_status_id                                     4
#  gender                                               F
#  income_type                                  сотрудник
#  debt                                                 0
#  total_income                             142594.396847
#  purpose             на покупку подержанного автомобиля
#  Name: 652, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   52
#  education                               Высшее
#  education_id                                 0
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       M
#  income_type                          сотрудник
#  debt                                         0
#  total_income                     142594.396847
#  purpose             покупка жилой недвижимости
#  Name: 653, dtype: object,
#  children                                  1
#  days_employed                           NaN
#  dob_years                                30
#  education                            высшее
#  education_id                              0
#  family_status               женат / замужем
#  family_status_id                          0
#  gender                                    F
#  income_type                     госслужащий
#  debt                                      0
#  total_income                  150447.935283
#  purpose             покупка жилья для семьи
#  Name: 680, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   45
#  education                               высшее
#  education_id                                 0
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       M
#  income_type                          сотрудник
#  debt                                         0
#  total_income                     142594.396847
#  purpose             покупка жилой недвижимости
#  Name: 681, dtype: object,
#  children                               0
#  days_employed                        NaN
#  dob_years                             43
#  education                        среднее
#  education_id                           1
#  family_status            женат / замужем
#  family_status_id                       0
#  gender                                 M
#  income_type                    сотрудник
#  debt                                   0
#  total_income               142594.396847
#  purpose             сделка с автомобилем
#  Name: 683, dtype: object,
#  children                                                 0
#  days_employed                                          NaN
#  dob_years                                               57
#  education                                          среднее
#  education_id                                             1
#  family_status                               вдовец / вдова
#  family_status_id                                         2
#  gender                                                   F
#  income_type                                      пенсионер
#  debt                                                     0
#  total_income                                 118514.486412
#  purpose             строительство собственной недвижимости
#  Name: 686, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                29
#  education                            высшее
#  education_id                              0
#  family_status               женат / замужем
#  family_status_id                          0
#  gender                                    F
#  income_type                       компаньон
#  debt                                      0
#  total_income                  172357.950966
#  purpose             покупка жилья для сдачи
#  Name: 712, dtype: object,
#  children                               0
#  days_employed                        NaN
#  dob_years                             52
#  education                         высшее
#  education_id                           0
#  family_status           гражданский брак
#  family_status_id                       1
#  gender                                 M
#  income_type                    сотрудник
#  debt                                   0
#  total_income               142594.396847
#  purpose             покупка недвижимости
#  Name: 713, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   51
#  education                              среднее
#  education_id                                 1
#  family_status            Не женат / не замужем
#  family_status_id                             4
#  gender                                       F
#  income_type                          сотрудник
#  debt                                         0
#  total_income                     142594.396847
#  purpose             покупка жилой недвижимости
#  Name: 719, dtype: object,
#  children                                0
#  days_employed                         NaN
#  dob_years                              26
#  education                          высшее
#  education_id                            0
#  family_status       Не женат / не замужем
#  family_status_id                        4
#  gender                                  M
#  income_type                     компаньон
#  debt                                    0
#  total_income                172357.950966
#  purpose                        автомобиль
#  Name: 724, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                52
#  education                           среднее
#  education_id                              1
#  family_status                     в разводе
#  family_status_id                          3
#  gender                                    F
#  income_type                       компаньон
#  debt                                      0
#  total_income                  172357.950966
#  purpose             покупка жилья для сдачи
#  Name: 736, dtype: object,
#  children                                          0
#  days_employed                                   NaN
#  dob_years                                        29
#  education                                   среднее
#  education_id                                      1
#  family_status                 Не женат / не замужем
#  family_status_id                                  4
#  gender                                            M
#  income_type                               сотрудник
#  debt                                              0
#  total_income                          142594.396847
#  purpose             операции со своей недвижимостью
#  Name: 743, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         54
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                сотрудник
#  debt                               0
#  total_income           142594.396847
#  purpose              сыграть свадьбу
#  Name: 760, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         21
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                компаньон
#  debt                               0
#  total_income           172357.950966
#  purpose                покупка жилья
#  Name: 763, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   48
#  education                               высшее
#  education_id                                 0
#  family_status            Не женат / не замужем
#  family_status_id                             4
#  gender                                       F
#  income_type                          компаньон
#  debt                                         0
#  total_income                     172357.950966
#  purpose             строительство недвижимости
#  Name: 788, dtype: object,
#  children                                0
#  days_employed                         NaN
#  dob_years                              57
#  education                         среднее
#  education_id                            1
#  family_status            гражданский брак
#  family_status_id                        1
#  gender                                  F
#  income_type                     компаньон
#  debt                                    0
#  total_income                172357.950966
#  purpose             получение образования
#  Name: 829, dtype: object,
#  children                                0
#  days_employed                         NaN
#  dob_years                              26
#  education                          высшее
#  education_id                            0
#  family_status       Не женат / не замужем
#  family_status_id                        4
#  gender                                  M
#  income_type                     компаньон
#  debt                                    0
#  total_income                172357.950966
#  purpose                     покупка жилья
#  Name: 830, dtype: object,
#  children                          1
#  days_employed                   NaN
#  dob_years                        33
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               сотрудник
#  debt                              0
#  total_income          142594.396847
#  purpose               покупка жилья
#  Name: 835, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         54
#  education                     высшее
#  education_id                       0
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                компаньон
#  debt                               0
#  total_income           172357.950966
#  purpose                      свадьба
#  Name: 849, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   56
#  education                              среднее
#  education_id                                 1
#  family_status            Не женат / не замужем
#  family_status_id                             4
#  gender                                       F
#  income_type                          сотрудник
#  debt                                         0
#  total_income                     142594.396847
#  purpose             дополнительное образование
#  Name: 851, dtype: object,
#  children                            2
#  days_employed                     NaN
#  dob_years                          24
#  education                      высшее
#  education_id                        0
#  family_status         женат / замужем
#  family_status_id                    0
#  gender                              M
#  income_type                 компаньон
#  debt                                0
#  total_income            172357.950966
# ...
#  purpose             строительство собственной недвижимости
#  Name: 9991, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                40
#  education                            высшее
#  education_id                              0
#  family_status         Не женат / не замужем
#  family_status_id                          4
#  gender                                    M
#  income_type                       компаньон
#  debt                                      0
#  total_income                  172357.950966
#  purpose             покупка жилья для семьи
#  Name: 9997, dtype: object,
#  children                                                0
#  days_employed                                         NaN
#  dob_years                                              36
#  education                                          высшее
#  education_id                                            0
#  family_status                             женат / замужем
#  family_status_id                                        0
#  gender                                                  F
#  income_type                                   госслужащий
#  debt                                                    0
#  total_income                                150447.935283
#  purpose             получение дополнительного образования
#  Name: 10008, dtype: object,
#  children                                            0
#  days_employed                                     NaN
#  dob_years                                          35
#  education                                      ВЫСШЕЕ
#  education_id                                        0
#  family_status                         женат / замужем
#  family_status_id                                    0
#  gender                                              F
#  income_type                                 компаньон
#  debt                                                1
#  total_income                            172357.950966
#  purpose             покупка коммерческой недвижимости
#  Name: 10013, dtype: object,
#  children                          0
#  days_employed                   NaN
#  dob_years                        67
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               пенсионер
#  debt                              0
#  total_income          118514.486412
#  purpose               покупка жилья
#  Name: 10019, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   53
#  education                               высшее
#  education_id                                 0
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       F
#  income_type                          компаньон
#  debt                                         0
#  total_income                     172357.950966
#  purpose             строительство недвижимости
#  Name: 10037, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   56
#  education                               высшее
#  education_id                                 0
#  family_status                   вдовец / вдова
#  family_status_id                             2
#  gender                                       F
#  income_type                          сотрудник
#  debt                                         0
#  total_income                     142594.396847
#  purpose             дополнительное образование
#  Name: 10042, dtype: object,
#  children                                1
#  days_employed                         NaN
#  dob_years                              33
#  education                         среднее
#  education_id                            1
#  family_status                   в разводе
#  family_status_id                        3
#  gender                                  F
#  income_type                     сотрудник
#  debt                                    0
#  total_income                142594.396847
#  purpose             заняться образованием
#  Name: 10053, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   55
#  education                              среднее
#  education_id                                 1
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       F
#  income_type                          пенсионер
#  debt                                         0
#  total_income                     118514.486412
#  purpose             строительство недвижимости
#  Name: 10059, dtype: object,
#  children                                1
#  days_employed                         NaN
#  dob_years                              31
#  education                          Высшее
#  education_id                            0
#  family_status            гражданский брак
#  family_status_id                        1
#  gender                                  F
#  income_type                     компаньон
#  debt                                    1
#  total_income                172357.950966
#  purpose             на проведение свадьбы
#  Name: 10076, dtype: object,
#  children                                                 0
#  days_employed                                          NaN
#  dob_years                                               52
#  education                              неоконченное высшее
#  education_id                                             2
#  family_status                              женат / замужем
#  family_status_id                                         0
#  gender                                                   F
#  income_type                                      пенсионер
#  debt                                                     0
#  total_income                                 118514.486412
#  purpose             строительство собственной недвижимости
#  Name: 10083, dtype: object,
#  children                               1
#  days_employed                        NaN
#  dob_years                             54
#  education                        среднее
#  education_id                           1
#  family_status            женат / замужем
#  family_status_id                       0
#  gender                                 F
#  income_type                    пенсионер
#  debt                                   0
#  total_income               118514.486412
#  purpose             покупка своего жилья
#  Name: 10090, dtype: object,
#  children                                  0
#  days_employed                           NaN
#  dob_years                                41
#  education                           среднее
#  education_id                              1
#  family_status              гражданский брак
#  family_status_id                          1
#  gender                                    F
#  income_type                       сотрудник
#  debt                                      1
#  total_income                  142594.396847
#  purpose             покупка жилья для семьи
#  Name: 10136, dtype: object,
#  children                       0
#  days_employed                NaN
#  dob_years                     48
#  education                среднее
#  education_id                   1
#  family_status          в разводе
#  family_status_id               3
#  gender                         F
#  income_type            сотрудник
#  debt                           1
#  total_income       142594.396847
#  purpose                    жилье
#  Name: 10137, dtype: object,
#  children                                                0
#  days_employed                                         NaN
#  dob_years                                              34
#  education                                         среднее
#  education_id                                            1
#  family_status                             женат / замужем
#  family_status_id                                        0
#  gender                                                  F
#  income_type                                     сотрудник
#  debt                                                    0
#  total_income                                142594.396847
#  purpose             операции с коммерческой недвижимостью
#  Name: 10141, dtype: object,
#  children                           1
#  days_employed                    NaN
#  dob_years                         60
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             F
#  income_type                пенсионер
#  debt                               0
#  total_income           118514.486412
#  purpose                      свадьба
#  Name: 10145, dtype: object,
#  children                          1
#  days_employed                   NaN
#  dob_years                        35
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               сотрудник
#  debt                              0
#  total_income          142594.396847
#  purpose               покупка жилья
#  Name: 10155, dtype: object,
#  children                                        0
#  days_employed                                 NaN
#  dob_years                                      40
#  education                                  высшее
#  education_id                                    0
#  family_status               Не женат / не замужем
#  family_status_id                                4
#  gender                                          F
#  income_type                             компаньон
#  debt                                            0
#  total_income                        172357.950966
#  purpose             получение высшего образования
#  Name: 10158, dtype: object,
#  children                                     0
#  days_employed                              NaN
#  dob_years                                   64
#  education                               высшее
#  education_id                                 0
#  family_status                  женат / замужем
#  family_status_id                             0
#  gender                                       F
#  income_type                        госслужащий
#  debt                                         0
#  total_income                     150447.935283
#  purpose             дополнительное образование
#  Name: 10197, dtype: object,
#  children                                1
#  days_employed                         NaN
#  dob_years                              27
#  education                         среднее
#  education_id                            1
#  family_status             женат / замужем
#  family_status_id                        0
#  gender                                  F
#  income_type                     сотрудник
#  debt                                    1
#  total_income                142594.396847
#  purpose             заняться образованием
#  Name: 10227, dtype: object,
#  children                          2
#  days_employed                   NaN
#  dob_years                        31
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            M
#  income_type               сотрудник
#  debt                              0
#  total_income          142594.396847
#  purpose                недвижимость
#  Name: 10229, dtype: object,
#  children                          2
#  days_employed                   NaN
#  dob_years                        29
#  education                   среднее
#  education_id                      1
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type             госслужащий
#  debt                              0
#  total_income          150447.935283
#  purpose                ремонт жилью
#  Name: 10243, dtype: object,
#  children                          1
#  days_employed                   NaN
#  dob_years                        33
#  education                    высшее
#  education_id                      0
#  family_status       женат / замужем
#  family_status_id                  0
#  gender                            F
#  income_type               компаньон
#  debt                              0
#  total_income          172357.950966
#  purpose                  автомобиль
#  Name: 10246, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         55
#  education                     высшее
#  education_id                       0
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                пенсионер
#  debt                               1
#  total_income           118514.486412
#  purpose                      свадьба
#  Name: 10268, dtype: object,
#  children                                0
#  days_employed                         NaN
#  dob_years                              43
#  education                         среднее
#  education_id                            1
#  family_status             женат / замужем
#  family_status_id                        0
#  gender                                  F
#  income_type                     сотрудник
#  debt                                    0
#  total_income                142594.396847
#  purpose             получение образования
#  Name: 10270, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         22
#  education                    среднее
#  education_id                       1
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                компаньон
#  debt                               1
#  total_income           172357.950966
#  purpose              сыграть свадьбу
#  Name: 10271, dtype: object,
#  children                                             0
#  days_employed                                      NaN
#  dob_years                                           44
#  education                                      СРЕДНЕЕ
#  education_id                                         1
#  family_status                          женат / замужем
#  family_status_id                                     0
#  gender                                               F
#  income_type                                  компаньон
#  debt                                                 0
#  total_income                             172357.950966
#  purpose             на покупку подержанного автомобиля
#  Name: 10286, dtype: object,
#  children                           0
#  days_employed                    NaN
#  dob_years                         49
#  education                     высшее
#  education_id                       0
#  family_status       гражданский брак
#  family_status_id                   1
#  gender                             M
#  income_type                сотрудник
#  debt                               0
#  total_income           142594.396847
#  purpose              сыграть свадьбу
#  Name: 10292, dtype: object,
#  children                                       0
#  days_employed                                NaN
#  dob_years                                     57
#  education                                среднее
#  education_id                                   1
#  family_status                    женат / замужем
#  family_status_id                               0
#  gender                                         M
#  income_type                            сотрудник
#  debt                                           0
#  total_income                       142594.396847
#  purpose             на покупку своего автомобиля
#  Name: 10310, dtype: object,
#  ...]

# %%
#Посмотрим какая медиана по `total_income` после преобразований:
df['total_income'].median()
# Out:
# 142594.39684740017

# %% [markdown]
# Пропуски в `total_income` заполнены медианой по группам.

# %% [markdown]
# ### Обработка аномалий и заполнение пропусков в `df` и `days_emploed`

# %%
#начнем с обработки значений в столбцах, для это выведем уникальные значения в каждом столбце:
for column in df:
    display(df[column].value_counts())
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64
# -327.685916     1
# -1580.622577    1
# -4122.460569    1
# -2828.237691    1
# -2636.090517    1
#                ..
# -7120.517564    1
# -2146.884040    1
# -881.454684     1
# -794.666350     1
# -3382.113891    1
# Name: days_employed, Length: 19351, dtype: int64
# 35    617
# 40    609
# 41    607
# 34    603
# 38    598
# 42    597
# 33    581
# 39    573
# 31    560
# 36    555
# 44    547
# 29    545
# 30    540
# 48    538
# 37    537
# 50    514
# 43    513
# 32    510
# 49    508
# 28    503
# 45    497
# 27    493
# 56    487
# 52    484
# 47    480
# 54    479
# 46    475
# 58    461
# 57    460
# 53    459
# 51    448
# 59    444
# 55    443
# 26    408
# 60    377
# 25    357
# 61    355
# 62    352
# 63    269
# 64    265
# 24    264
# 23    254
# 65    194
# 66    183
# 22    183
# 67    167
# 21    111
# 0     101
# 68     99
# 69     85
# 70     65
# 71     58
# 20     51
# 72     33
# 19     14
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# Name: education, dtype: int64
# 1    15233
# 0     5260
# 2      744
# 3      282
# 4        6
# Name: education_id, dtype: int64
# женат / замужем          12380
# гражданский брак          4177
# Не женат / не замужем     2813
# в разводе                 1195
# вдовец / вдова             960
# Name: family_status, dtype: int64
# 0    12380
# 1     4177
# 4     2813
# 3     1195
# 2      960
# Name: family_status_id, dtype: int64
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64
# сотрудник          11119
# компаньон           5085
# пенсионер           3856
# госслужащий         1459
# безработный            2
# предприниматель        2
# студент                1
# в декрете              1
# Name: income_type, dtype: int64
# 0    19784
# 1     1741
# Name: debt, dtype: int64
# 142594.396847    1105
# 172357.950966     509
# 118514.486412     414
# 150447.935283     147
# 499163.144947       2
#                  ...
# 101516.604975       1
# 239154.168013       1
# 165009.733021       1
# 94270.049769        1
# 189255.286637       1
# Name: total_income, Length: 19353, dtype: int64
# свадьба                                   797
# на проведение свадьбы                     777
# сыграть свадьбу                           774
# операции с недвижимостью                  676
# покупка коммерческой недвижимости         664
# операции с жильем                         653
# покупка жилья для сдачи                   653
# операции с коммерческой недвижимостью     651
# покупка жилья                             647
# жилье                                     647
# покупка жилья для семьи                   641
# строительство собственной недвижимости    635
# недвижимость                              634
# операции со своей недвижимостью           630
# строительство жилой недвижимости          626
# покупка недвижимости                      624
# строительство недвижимости                620
# покупка своего жилья                      620
# ремонт жилью                              612
# покупка жилой недвижимости                607
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                495
# сделка с подержанным автомобилем          489
# свой автомобиль                           480
# на покупку подержанного автомобиля        479
# автомобили                                478
# на покупку автомобиля                     472
# дополнительное образование                462
# приобретение автомобиля                   462
# сделка с автомобилем                      455
# высшее образование                        453
# образование                               447
# получение дополнительного образования     447
# получение образования                     443
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     412
# Name: purpose, dtype: int64

# %% [markdown]
# Что нужно обработать:
# 1) В столбце `children` данные распределены между от -1 до 20, часть данных выглядит нереалистично, показатель -1 и 20 выбивается из общего ряда. Так как данный показатель важен для цели исследования, посмотрим какую долю от общего количества данных и какую долю от общего количества детей занимают аномалии.
#
# 2) В столбце `dob_years` есть показатель с 0, возможно это опечатка с 20 или с 30.
#
# 3) В `gender` есть одна строка с показателем `XNA`, просто удалим ее.
#
# 4) В столбце `days_employed` присутствуют отрицательные данные, пропуски, а также есть выбросы, нужно посмотреть поближе, чтобы сказать почему могли возникнуть аномалии. Привести к целочисленному значению.
#
#
# Потом:
#
# * В `total_income` привести к целочисленному значению.
#
# * Удалить строки дубликаты
#
# * В `family_status` данные не дублируются, но нарушен нижний регистр.
#
# * В столбце `education` нарушен регистр.
#
# * В `family_status` данные не дублируются, но нарушен нижний регистр.
#
# * В `purpose` в данных очень много неявных дубликатов.

# %% [markdown]
# #### Обработка `children`

# %%
df['children'].value_counts()
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %%
# Посчитаем количество аномальных данных в столбце `children`:
anomaly_children = df.loc[(df['children'] == -1) | (df['children'] == 20)]['children'].count()
anomaly_children
# Out:
# 123

# %%
# Посчитаем количество правдивых данных с детьми в столбце `children`:
not_anomaly_choldren = df.loc[df['children'] != 0]['children'].count() - anomaly_children
not_anomaly_choldren
# Out:
# 7253

# %%
print('Отношение аномалий в `children` ко всем заемщикам равно {:.1%}'.format(anomaly_children/len(df['children'])))
print('Отношение аномалий в `children` ко всем заемщикам с детьми равно {:.1%}'.format(anomaly_children/not_anomaly_choldren))
# Out:
# Отношение аномалий в `children` ко всем заемщикам равно 0.6%
# Отношение аномалий в `children` ко всем заемщикам с детьми равно 1.7%

# %% [markdown]
# Показатель важен, будем считать, что это опечатка, тогда обработаем аномалии по принципу:
#
# * -1 это опечатка от 1
# * 20 это опечатка от 2, так как предыдущий максимальный показатель 5 и между 5 и 20 нет никаких данных.

# %%
# Заменяем значения:
df['children'] = df['children'].replace(-1, 1)
df['children'] = df['children'].replace(20, 2)
#Проверяем:
df['children'].value_counts()
# Out:
# 0    14149
# 1     4865
# 2     2131
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличное решение!
# </div>

# %% [markdown]
# #### Обработка `dob_years`

# %%
#Смотрим сколько данных с значением 0:
df.loc[df['dob_years'] == 0]['dob_years'].count()
# Out:
# 101

# %%
print('''Процентное соотношение данных с 0 ко всей таблице равно {:.1%}'''
      .format(df.loc[df['dob_years'] == 0]['dob_years'].count()/len(df['dob_years'])))
# Out:
# Процентное соотношение данных с 0 ко всей таблице равно 0.5%

# %% [markdown]
# Данные незначительны, к тому же, трудно восстановить такие данные, это может быть опечатка от 20, 30 и тд. Просто удалим данные строчки:

# %%
# Удаляем строчки с `dob_years` = 0:
df = df.loc[df['dob_years'] != 0]
# Проверяем:
df.loc[df['dob_years'] == 0]['dob_years'].count()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👍
# </div>

# %% [markdown]
# #### Обработка `gender`

# %%
df['gender'].value_counts()
# Out:
# F      14164
# M       7259
# XNA        1
# Name: gender, dtype: int64

# %%
# В данных присутствует один неизвестный пол, просто удалим строчку:
df = df.loc[df['gender'] != 'XNA']

# %%
# Провеярем:
df['gender'].value_counts()
# Out:
# F    14164
# M     7259
# Name: gender, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Поддерживаю! Так как мы не можем достоверно сказать, к какому полу ближе это значение, его стоит или удалить или не трогать)
# </div>

# %% [markdown]
# #### Обработка `days_employed`

# %% [markdown]
# Будем считать, что отрицательные данные в `days_employed` возникли из за опечатки. Возведем отрицательные значения в абсолютные. Также оценим сколько выбросов в данных.

# %%
# Узнаем, удалились ли пустые строчки в `days_employed`:
df.isna().sum()
# Out:
# children               0
# days_employed       2164
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income           0
# purpose                0
# dtype: int64

# %%
#Посмотрим какой % данных в столбце 'days_employed' отрицательный:
print('Отрицательный процент данных в `days_employed` равен {:.1%} '
      .format(df.loc[df['days_employed'] < 0]['days_employed'].count() / len(df['days_employed'])))
# Out:
# Отрицательный процент данных в `days_employed` равен 73.9%

# %%
#Приведем данные к абсолютному значению:
df['days_employed'] = abs(df['days_employed'])
#Проверим:
df['days_employed'].describe()
# Out:
# count    19259.000000
# mean     66905.789237
# std     139025.028132
# min         24.141633
# 25%        926.823974
# 50%       2197.320350
# 75%       5540.399763
# max     401755.400475
# Name: days_employed, dtype: float64

# %% [markdown]
# В данных наблюдаются аномалии по количеству рабочих дней в трудовом стаже. Предположим, что каждый заемщик начал трудовую деятельность в 16 лет, тогда посчитаем, у какого количества заемщиков данные неправдивы:

# %%
df.loc[df['days_employed'] > (df['dob_years']-16)*365]['days_employed'].count()
# Out:
# 3517

# %%
# Посмотрим процентное соотношение выбросов при условии, что человека с рождения начал трудовую деятельность:
print('''Процент выбросов в `days_employed` равен {:.1%} '''
      .format(df.loc[df['days_employed'] > (df['dob_years'])*365]['days_employed'].count() / len(df['days_employed'])))
# Out:
# Процент выбросов в `days_employed` равен 16.0%

# %%
# Процентное отношение выбросов, при условии, что человек начал трудовую деятельность с 16 лет:
print('''Процент выбросов в `days_employed` равен {:.1%} '''
      .format(df.loc[df['days_employed'] > (df['dob_years']-16)*365]['days_employed'].count() / len(df['days_employed'])))
# Out:
# Процент выбросов в `days_employed` равен 16.4%

# %%
# Пройдемся по столбцу `days_employed` и поменяем все выбросы на `NaN`:
for ind in df.index:
    if df.loc[ind,'days_employed'] > (df.loc[ind, 'dob_years'] - 16)*365:
        df.loc[ind, 'days_employed'] = np.nan
# Проверим себя, ранее мы увидили, что после удаления 101 строки с нулевым значением в `dob_years` и 1 строки в `gender`
# уменьшилось количество пропусков в `days_employed` и стало равно 2164, а также мы знаем что аномалий 
# в `days_employed`3835 => после замены аномалий на `NaN` количество пропусков будет равно 2164+3517 = 5681:
df.isna().sum()
# Out:
# children               0
# days_employed       5681
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income           0
# purpose                0
# dtype: int64

# %% [markdown]
# На данном этапе нужно заполнить пропуски в столбце `days_employed`, попробуем это сделать 3 разными способами, разными по точности:
# 1) Создадим столбец `days_employed_v1`, где пропуски заполним просто медианным значением по всему столбцу.
#
# 2) Создадим столбец `days_employed_v2`, где пропуски будем заполнять медианным значением по каждому возрасту.
#
# 3) Создадим столбец `avg_days_employed_on_dob_years`, в котором мы посчитатем сколько каждый человек в среднем работал за год трудовой деятельности, затем возьмем медиану от этого столбца и заполним пропуски путем умножения полученного показателя на количество лет трудовой деятельности. Результат в `days_employed_v3`

# %%
df['days_employed_v1'] = df['days_employed'].fillna(df['days_employed'].median())

# %%
df['days_employed_v2'] = df['days_employed'].fillna(df.groupby('dob_years')['days_employed'].transform('median'))

# %%
df['avg_days_employed_on_dob_years'] = df['days_employed'] / (df['dob_years']-16)
df['days_employed_v3'] = df['days_employed'].fillna(df['avg_days_employed_on_dob_years'].median()*(df['dob_years']-16))

# %%
df = df.drop(columns=['avg_days_employed_on_dob_years'], axis = 1)

# %%
df.describe()
# Out:
#           children  days_employed    dob_years  education_id  \
# count 21423.000000   15742.000000 21423.000000  21423.000000
# mean      0.479671    2315.566043    43.498390      0.817859
# std       0.755304    2235.452068    12.246495      0.548178
# min       0.000000      24.141633    19.000000      0.000000
# 25%       0.000000     751.731878    33.000000      1.000000
# 50%       0.000000    1618.778311    43.000000      1.000000
# 75%       1.000000    3123.510043    53.000000      1.000000
# max       5.000000   16119.687737    75.000000      4.000000
#
#        family_status_id         debt   total_income  days_employed_v1  \
# count      21423.000000 21423.000000   21423.000000      21423.000000
# mean           0.971293     0.080894  165263.932208       2130.790283
# std            1.419770     0.272679   98154.893805       1940.776862
# min            0.000000     0.000000   20667.263793         24.141633
# 25%            0.000000     0.000000  107822.087173       1025.636694
# 50%            0.000000     0.000000  142594.396847       1618.778311
# 75%            1.000000     0.000000  195514.663363       2481.888048
# max            4.000000     1.000000 2265604.028723      16119.687737
#
#        days_employed_v2  days_employed_v3
# count      21423.000000      21423.000000
# mean        2307.711100       2482.115175
# std         1954.506535       1996.366886
# min           24.141633         24.141633
# 25%         1005.572367        975.890080
# 50%         1974.658141       2138.099890
# 75%         2830.361431       3461.093267
# max        16119.687737      16119.687737

# %%
# Медиана первым способом:
df['days_employed_v1'].median()
# Out:
# 1618.778311069244

# %%
# Медиана вторым способом:
df['days_employed_v2'].median()
# Out:
# 1974.6581408064328

# %%
# Медиана третьим способом: 
df['days_employed_v3'].median()
# Out:
# 2138.099889779742

# %% [markdown]
# Оценив данные, мне кажется, что самым приближенным показателем является медиана, посчитанная 3им способом. Заполним пропущенные значения в `days_employed` медианой из 3го способа и удалим лишние столбцы.

# %%
# посмотрим чем будем заполнять:
df['days_employed_v3'].value_counts()
# Out:
# 3405.122047    290
# 3484.310931    283
# 3642.688701    273
# 3246.744277    269
# 3325.933162    264
#               ...
# 235.478590       1
# 2084.594903      1
# 4412.753314      1
# 382.908057       1
# 1636.419775      1
# Name: days_employed_v3, Length: 15798, dtype: int64

# %%
# Меняем:
df['days_employed'] = df['days_employed_v3']

# %%
# Проверяем:
df.describe()
# Out:
#           children  days_employed    dob_years  education_id  \
# count 21423.000000   21423.000000 21423.000000  21423.000000
# mean      0.479671    2482.115175    43.498390      0.817859
# std       0.755304    1996.366886    12.246495      0.548178
# min       0.000000      24.141633    19.000000      0.000000
# 25%       0.000000     975.890080    33.000000      1.000000
# 50%       0.000000    2138.099890    43.000000      1.000000
# 75%       1.000000    3461.093267    53.000000      1.000000
# max       5.000000   16119.687737    75.000000      4.000000
#
#        family_status_id         debt   total_income  days_employed_v1  \
# count      21423.000000 21423.000000   21423.000000      21423.000000
# mean           0.971293     0.080894  165263.932208       2130.790283
# std            1.419770     0.272679   98154.893805       1940.776862
# min            0.000000     0.000000   20667.263793         24.141633
# 25%            0.000000     0.000000  107822.087173       1025.636694
# 50%            0.000000     0.000000  142594.396847       1618.778311
# 75%            1.000000     0.000000  195514.663363       2481.888048
# max            4.000000     1.000000 2265604.028723      16119.687737
#
#        days_employed_v2  days_employed_v3
# count      21423.000000      21423.000000
# mean        2307.711100       2482.115175
# std         1954.506535       1996.366886
# min           24.141633         24.141633
# 25%         1005.572367        975.890080
# 50%         1974.658141       2138.099890
# 75%         2830.361431       3461.093267
# max        16119.687737      16119.687737

# %%
# Удаляем:
df = df.drop(columns=['days_employed_v1','days_employed_v2','days_employed_v3'], axis = 1)

# %%
# Смотрим и проверяем:
df.head()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0    2929.988738         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0 253875.639453
# 1   женат / замужем                 0      F   сотрудник     0 112080.014102
# 2   женат / замужем                 0      M   сотрудник     0 145885.952297
# 3   женат / замужем                 0      M   сотрудник     0 267628.550329
# 4  гражданский брак                 1      F   пенсионер     0 158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу

# %%
# Еще раз:
df.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👏🏻👏🏻👏🏻 Отличная работа с аномальными значениями и пропусками. Молодец!
# </div>

# %% [markdown]
# ### Замена типа данных в `total_income`

# %%
# Приводим к целочисленным значениям:
df['total_income'] = df['total_income'].astype('int')

# %%
# Проверяем:
df.loc[df['total_income'] < 0]['total_income'].count()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Тут всё верно!
# </div>

# %% [markdown]
# ### Обработка  на дубликаты:

# %% [markdown]
# #### Обработка неявных дубликатов

# %%
# Проверим, какое количество дубликатов дошло до этого этапа:
df.duplicated().sum()
# Out:
# 54

# %%
df['education'].value_counts()
# Out:
# среднее                13691
# высшее                  4686
# СРЕДНЕЕ                  770
# Среднее                  708
# неоконченное высшее      665
# ВЫСШЕЕ                   273
# Высшее                   266
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# Name: education, dtype: int64

# %%
# Приводим к нижнему регистру:
df['education'] = df['education'].str.lower()

# %%
# Проверям: 
df['education'].value_counts()
# Out:
# среднее                15169
# высшее                  5225
# неоконченное высшее      741
# начальное                282
# ученая степень             6
# Name: education, dtype: int64

# %%
# Посмотрим, сколько дубликатов стало после обработки столбца `education`:
df.duplicated().sum()
# Out:
# 71

# %% [markdown]
# Заодно приведем `family_status` к нижнему регистру.

# %%
df['family_status'].value_counts()
# Out:
# женат / замужем          12331
# гражданский брак          4155
# Не женат / не замужем     2797
# в разводе                 1185
# вдовец / вдова             955
# Name: family_status, dtype: int64

# %%
df['family_status'] = df['family_status'].str.lower()

# %%
df['family_status'].value_counts()
# Out:
# женат / замужем          12331
# гражданский брак          4155
# не женат / не замужем     2797
# в разводе                 1185
# вдовец / вдова             955
# Name: family_status, dtype: int64

# %% [markdown]
# #### Удаление строк-дубликатов

# %%
# Посмотрим сколько дубликатов было в сырых данных:
df_raw.duplicated().sum()
# Out:
# 54

# %%
# Посмотрим на эти дубликаты:
df.loc[df.duplicated() == True]
# Out:
#        children  days_employed  dob_years education  education_id  \
# 2849          0    1979.722120         41   среднее             1
# 3290          0    3325.933162         58   среднее             1
# 4182          1    1425.399927         34    высшее             0
# 4851          0    3484.310931         60   среднее             1
# 5557          0    3325.933162         58   среднее             1
# ...         ...            ...        ...       ...           ...
# 20702         0    3801.066471         64   среднее             1
# 21032         0    3484.310931         60   среднее             1
# 21132         0    2454.855429         47   среднее             1
# 21281         1    1108.644387         30    высшее             0
# 21415         0    3009.177623         54   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 2849    женат / замужем                 0      F   сотрудник     0
# 3290   гражданский брак                 1      F   пенсионер     0
# 4182   гражданский брак                 1      F   сотрудник     0
# 4851   гражданский брак                 1      F   пенсионер     0
# 5557   гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 20702   женат / замужем                 0      F   пенсионер     0
# 21032   женат / замужем                 0      F   пенсионер     0
# 21132   женат / замужем                 0      F   сотрудник     0
# 21281   женат / замужем                 0      F   сотрудник     0
# 21415   женат / замужем                 0      F   пенсионер     0
#
#        total_income                            purpose
# 2849         142594            покупка жилья для семьи
# 3290         118514                    сыграть свадьбу
# 4182         142594                            свадьба
# 4851         118514                            свадьба
# 5557         118514                    сыграть свадьбу
# ...             ...                                ...
# 20702        118514         дополнительное образование
# 21032        118514              заняться образованием
# 21132        142594                       ремонт жилью
# 21281        142594  покупка коммерческой недвижимости
# 21415        118514                  операции с жильем
#
# [71 rows x 12 columns]

# %%
# Посмотрим на дубликаты в сырых данных:
df_raw.loc[df_raw.duplicated() == True]
# Out:
#        children  days_employed  dob_years education  education_id  \
# 2849          0            NaN         41   среднее             1
# 4182          1            NaN         34    ВЫСШЕЕ             0
# 4851          0            NaN         60   среднее             1
# 5557          0            NaN         58   среднее             1
# 7808          0            NaN         57   среднее             1
# 8583          0            NaN         58    высшее             0
# 9238          2            NaN         34   среднее             1
# 9528          0            NaN         66   среднее             1
# 9627          0            NaN         56   среднее             1
# 10462         0            NaN         62   среднее             1
# 10697         0            NaN         40   среднее             1
# 10864         0            NaN         62   среднее             1
# 10994         0            NaN         62   среднее             1
# 11791         0            NaN         47   среднее             1
# 12373         0            NaN         58   среднее             1
# 12375         1            NaN         37   среднее             1
# 12736         0            NaN         59   среднее             1
# 13025         1            NaN         44   среднее             1
# 13639         0            NaN         64   среднее             1
# 13773         0            NaN         35   среднее             1
# 13878         1            NaN         31   среднее             1
# 13942         0            NaN         44   среднее             1
# 14432         2            NaN         36    высшее             0
# 14832         0            NaN         50   среднее             1
# 15091         0            NaN         58   среднее             1
# 15188         0            NaN         60   среднее             1
# 15273         0            NaN         57   среднее             1
# 16176         0            NaN         47   среднее             1
# 16378         0            NaN         46   среднее             1
# 16902         2            NaN         39   среднее             1
# 16904         1            NaN         32    высшее             0
# 17379         0            NaN         54    высшее             0
# 17755         1            NaN         43   среднее             1
# 17774         1            NaN         40   среднее             1
# 18328         0            NaN         29    высшее             0
# 18349         1            NaN         30    высшее             0
# 18428         0            NaN         64   среднее             1
# 18521         0            NaN         56   среднее             1
# 18563         0            NaN         54   среднее             1
# 18755         0            NaN         58   среднее             1
# 19041         0            NaN         56   среднее             1
# 19184         0            NaN         46   среднее             1
# 19321         0            NaN         23   среднее             1
# 19387         0            NaN         38    высшее             0
# 19688         0            NaN         61   среднее             1
# 19832         0            NaN         48   среднее             1
# 19946         0            NaN         57   среднее             1
# 20116         0            NaN         57   среднее             1
# 20165         0            NaN         42   среднее             1
# 20702         0            NaN         64   среднее             1
# 21032         0            NaN         60   среднее             1
# 21132         0            NaN         47   среднее             1
# 21281         1            NaN         30    высшее             0
# 21415         0            NaN         54   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 2849         женат / замужем                 0      F    сотрудник     0
# 4182        гражданский брак                 1      F    сотрудник     0
# 4851        гражданский брак                 1      F    пенсионер     0
# 5557        гражданский брак                 1      F    пенсионер     0
# 7808        гражданский брак                 1      F    пенсионер     0
# 8583   Не женат / не замужем                 4      F    пенсионер     0
# 9238         женат / замужем                 0      F    сотрудник     0
# 9528          вдовец / вдова                 2      F    пенсионер     0
# 9627         женат / замужем                 0      F    пенсионер     0
# 10462        женат / замужем                 0      F    пенсионер     0
# 10697       гражданский брак                 1      F    компаньон     0
# 10864        женат / замужем                 0      F    пенсионер     0
# 10994        женат / замужем                 0      F    пенсионер     0
# 11791        женат / замужем                 0      F    сотрудник     0
# 12373        женат / замужем                 0      M    сотрудник     0
# 12375        женат / замужем                 0      F    сотрудник     0
# 12736        женат / замужем                 0      F    пенсионер     0
# 13025        женат / замужем                 0      F    сотрудник     0
# 13639        женат / замужем                 0      F    пенсионер     0
# 13773       гражданский брак                 1      F    сотрудник     0
# 13878        женат / замужем                 0      F    компаньон     0
# 13942        женат / замужем                 0      F    сотрудник     0
# 14432        женат / замужем                 0      F  госслужащий     0
# 14832  Не женат / не замужем                 4      F    сотрудник     0
# 15091       гражданский брак                 1      M    сотрудник     0
# 15188        женат / замужем                 0      M    сотрудник     0
# 15273       гражданский брак                 1      F    пенсионер     0
# 16176        женат / замужем                 0      F    сотрудник     0
# 16378        женат / замужем                 0      F    сотрудник     0
# 16902       гражданский брак                 1      F    сотрудник     0
# 16904        женат / замужем                 0      F    сотрудник     0
# 17379        женат / замужем                 0      M    компаньон     0
# 17755        женат / замужем                 0      M    сотрудник     0
# 17774       гражданский брак                 1      F    компаньон     0
# 18328        женат / замужем                 0      M    сотрудник     0
# 18349        женат / замужем                 0      F  госслужащий     0
# 18428        женат / замужем                 0      F    пенсионер     0
# 18521       гражданский брак                 1      F    сотрудник     0
# 18563        женат / замужем                 0      F    сотрудник     0
# 18755        женат / замужем                 0      F    пенсионер     0
# 19041       гражданский брак                 1      F    сотрудник     0
# 19184        женат / замужем                 0      F    сотрудник     0
# 19321  Не женат / не замужем                 4      F    сотрудник     0
# 19387       гражданский брак                 1      F    компаньон     0
# 19688        женат / замужем                 0      F    пенсионер     0
# 19832        женат / замужем                 0      F    сотрудник     0
# 19946        женат / замужем                 0      F    сотрудник     0
# 20116       гражданский брак                 1      M    пенсионер     0
# 20165        женат / замужем                 0      F    сотрудник     0
# 20702        женат / замужем                 0      F    пенсионер     0
# 21032        женат / замужем                 0      F    пенсионер     0
# 21132        женат / замужем                 0      F    сотрудник     0
# 21281        женат / замужем                 0      F    сотрудник     0
# 21415        женат / замужем                 0      F    пенсионер     0
#
#        total_income                                purpose
# 2849            NaN                покупка жилья для семьи
# 4182            NaN                                свадьба
# 4851            NaN                                свадьба
# 5557            NaN                        сыграть свадьбу
# 7808            NaN                  на проведение свадьбы
# 8583            NaN             дополнительное образование
# 9238            NaN                покупка жилья для сдачи
# 9528            NaN        операции со своей недвижимостью
# 9627            NaN        операции со своей недвижимостью
# 10462           NaN      покупка коммерческой недвижимости
# 10697           NaN                        сыграть свадьбу
# 10864           NaN                           ремонт жилью
# 10994           NaN                           ремонт жилью
# 11791           NaN             строительство недвижимости
# 12373           NaN                   покупка недвижимости
# 12375           NaN                   покупка недвижимости
# 12736           NaN                  заняться образованием
# 13025           NaN       сделка с подержанным автомобилем
# 13639           NaN                             автомобиль
# 13773           NaN                        сыграть свадьбу
# 13878           NaN                          покупка жилья
# 13942           NaN                приобретение автомобиля
# 14432           NaN                  получение образования
# 14832           NaN                           недвижимость
# 15091           NaN                  на проведение свадьбы
# 15188           NaN                   покупка недвижимости
# 15273           NaN                                свадьба
# 16176           NaN                           ремонт жилью
# 16378           NaN                     высшее образование
# 16902           NaN                        сыграть свадьбу
# 16904           NaN     на покупку подержанного автомобиля
# 17379           NaN  операции с коммерческой недвижимостью
# 17755           NaN                  заняться образованием
# 17774           NaN       строительство жилой недвижимости
# 18328           NaN             покупка жилой недвижимости
# 18349           NaN                покупка жилья для семьи
# 18428           NaN                                  жилье
# 18521           NaN                        сыграть свадьбу
# 18563           NaN        операции со своей недвижимостью
# 18755           NaN                  заняться образованием
# 19041           NaN                  на проведение свадьбы
# 19184           NaN                        свой автомобиль
# 19321           NaN       сделка с подержанным автомобилем
# 19387           NaN                  на проведение свадьбы
# 19688           NaN               операции с недвижимостью
# 19832           NaN                           ремонт жилью
# 19946           NaN       сделка с подержанным автомобилем
# 20116           NaN                                свадьба
# 20165           NaN                покупка жилья для семьи
# 20702           NaN             дополнительное образование
# 21032           NaN                  заняться образованием
# 21132           NaN                           ремонт жилью
# 21281           NaN      покупка коммерческой недвижимости
# 21415           NaN                      операции с жильем

# %% [markdown]
# В сырых данных дубликаты были из за наличия `NaN` в столбцах `days_employed` и `total_income`, в обработанных данных, хоть мы и обрабатывали количественные столбцы разными способами, дубликатов перенеслись. Это видно, если посмотреть, на строчку `4851`, в этой строке показатели в столбцах `days_employed` и `total_income` идентичны тем, что мы вставляли, когда заполняли пропуски. Ниже приведу данные, которые мы вставляли в пропуски. Также после обработки столбца`education` вылезли новые дубликаты.  До обработки столбца`education` дубликатов было 54. Стало 71.
#
# ```Данные для заполнения `total_income`:
# income_type
# безработный       131339.751676
# в декрете          53829.130729
# госслужащий       150447.935283
# компаньон         172357.950966
# пенсионер         118514.486412
# предприниматель   499163.144947
# сотрудник         142594.396847
# студент            98201.625314```
#
# ```Часть данных для заполнения `days_employed`:
# 3405.663978    290
# 3484.865466    283
# 3643.268441    273
# 3247.261002    269
# 3326.462490    264```

# %%
# Удалим дубликаты: 
df = df.drop_duplicates().reset_index(drop=True)

# %%
# Проверим: 
df.duplicated().sum()
# Out:
# 0

# %%
df['purpose'].value_counts()
# Out:
# свадьба                                   786
# на проведение свадьбы                     764
# сыграть свадьбу                           760
# операции с недвижимостью                  672
# покупка коммерческой недвижимости         658
# покупка жилья для сдачи                   649
# операции с коммерческой недвижимостью     648
# операции с жильем                         646
# жилье                                     640
# покупка жилья                             640
# покупка жилья для семьи                   637
# строительство собственной недвижимости    633
# недвижимость                              629
# операции со своей недвижимостью           627
# строительство жилой недвижимости          621
# строительство недвижимости                619
# покупка своего жилья                      619
# покупка недвижимости                      617
# ремонт жилью                              605
# покупка жилой недвижимости                603
# на покупку своего автомобиля              502
# заняться высшим образованием              493
# автомобиль                                490
# сделка с подержанным автомобилем          484
# на покупку подержанного автомобиля        478
# автомобили                                476
# свой автомобиль                           475
# на покупку автомобиля                     466
# приобретение автомобиля                   459
# дополнительное образование                458
# сделка с автомобилем                      454
# высшее образование                        449
# образование                               444
# получение дополнительного образования     444
# получение образования                     441
# профильное образование                    435
# получение высшего образования             424
# заняться образованием                     407
# Name: purpose, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! От дубликатов тоже избавились
# </div>

# %% [markdown]
# ### Создание "словарей"

# %% [markdown]
# Создадим два новых датафрейма:
# * `df_education_id`, в котором каждому уникальному значению из `education` соответствует уникальное значение `education_id`
#
# * `df_family_status_id` в котором каждому уникальному значению из `family_status` соответствует уникальное значение `family_status_id`
#
# Затем удалим из `df` столбцы `education` и `family_status`:

# %%
# Создаем:
df_education_id = df[['education_id', 'education']]
df_family_status_id = df[['family_status_id','family_status']]
# Удаляем:
df = df.drop(columns=['family_status', 'education'], axis = 1)

# %%
# Проверяем:
df.head()
# Out:
#    children  days_employed  dob_years  education_id  family_status_id gender  \
# 0         1    8437.673028         42             0                 0      F
# 1         1    4024.803754         36             1                 0      F
# 2         0    5623.422610         33             1                 0      M
# 3         3    4124.747207         32             1                 0      M
# 4         0    2929.988738         53             1                 1      F
#
#   income_type  debt  total_income                     purpose
# 0   сотрудник     0        253875               покупка жилья
# 1   сотрудник     0        112080     приобретение автомобиля
# 2   сотрудник     0        145885               покупка жилья
# 3   сотрудник     0        267628  дополнительное образование
# 4   пенсионер     0        158616             сыграть свадьбу

# %%
# Удаляем дубликаты:
df_education_id = df_education_id.drop_duplicates().reset_index(drop=True)

# %%
# Удаляем дубликаты:
df_family_status_id = df_family_status_id.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Тут всё правильно 👌
# </div>

# %% [markdown]
# ### Создание категории `total_income_category`

# %% [markdown]
# На основании диапазонов, указанных ниже, создадим столбец total_income_category с категориями:
#
# `0–30000 — 'E'`;
#
# `30001–50000 — 'D'`;
#
# `50001–200000 — 'C'`;
#
# `200001–1000000 — 'B'`;
#
# `1000001 и выше — 'A'`.
#
# Например, кредитополучателю с доходом 25000 нужно назначить категорию 'E', а клиенту, получающему 235000, — 'B'.
# Чтобы разбить на категории, напишем функцию:

# %%
def income_categories(income):
    if 0 < income < 30000:
        return 'E'
    elif 30001 < income < 50000:
        return 'D'
    elif 50001 < income < 200000:
        return 'C'
    elif 200001 < income < 1000000:
        return 'B'
    elif income > 1000001: 
        return 'A'

# %% [markdown]
# Создадим столбец `total_income_category` и с помощью метода `apply()` перенесем результаты функции `income_categories`, метод `apply()` будем вызывать к столбцу `total_income`:

# %%
df['total_income_category'] = df['total_income'].apply(income_categories)
df.head()
# Out:
#    children  days_employed  dob_years  education_id  family_status_id gender  \
# 0         1    8437.673028         42             0                 0      F
# 1         1    4024.803754         36             1                 0      F
# 2         0    5623.422610         33             1                 0      M
# 3         3    4124.747207         32             1                 0      M
# 4         0    2929.988738         53             1                 1      F
#
#   income_type  debt  total_income                     purpose  \
# 0   сотрудник     0        253875               покупка жилья
# 1   сотрудник     0        112080     приобретение автомобиля
# 2   сотрудник     0        145885               покупка жилья
# 3   сотрудник     0        267628  дополнительное образование
# 4   пенсионер     0        158616             сыграть свадьбу
#
#   total_income_category
# 0                     B
# 1                     C
# 2                     C
# 3                     B
# 4                     C

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Категоризация клиентов по уровню дохода произведена верно
# </div>

# %% [markdown]
# ### Создание категории `purpose_category`

# %% [markdown]
# Создадим функцию, которая на основании данных из столбца purpose сформирует новый столбец purpose_category, в который войдут следующие категории:
#
# `операции с автомобилем`,
#
# `операции с недвижимостью`,
#
# `проведение свадьбы`,
#
# `получение образования`.

# %%
# Посмотрим на возможные категории:
df['purpose'].value_counts()
# Out:
# свадьба                                   786
# на проведение свадьбы                     764
# сыграть свадьбу                           760
# операции с недвижимостью                  672
# покупка коммерческой недвижимости         658
# покупка жилья для сдачи                   649
# операции с коммерческой недвижимостью     648
# операции с жильем                         646
# жилье                                     640
# покупка жилья                             640
# покупка жилья для семьи                   637
# строительство собственной недвижимости    633
# недвижимость                              629
# операции со своей недвижимостью           627
# строительство жилой недвижимости          621
# строительство недвижимости                619
# покупка своего жилья                      619
# покупка недвижимости                      617
# ремонт жилью                              605
# покупка жилой недвижимости                603
# на покупку своего автомобиля              502
# заняться высшим образованием              493
# автомобиль                                490
# сделка с подержанным автомобилем          484
# на покупку подержанного автомобиля        478
# автомобили                                476
# свой автомобиль                           475
# на покупку автомобиля                     466
# приобретение автомобиля                   459
# дополнительное образование                458
# сделка с автомобилем                      454
# высшее образование                        449
# образование                               444
# получение дополнительного образования     444
# получение образования                     441
# профильное образование                    435
# получение высшего образования             424
# заняться образованием                     407
# Name: purpose, dtype: int64

# %%
def purpose_categories(row):
    if 'свадьб' in row:
        return 'проведение свадьбы'
    
    elif 'недвижимост' in row:
        return 'операции с недвижимостью'
    
    elif 'автомобил' in row:
        return 'операции с автомобилем'
    
    elif 'образовани' in row:
        return 'получение образования'
        
    elif 'жил' in row:
        return 'операции с недвижимостью'
    else:
        return 'другое'

# %%
df['purpose_category'] = df['purpose'].apply(purpose_categories)

# %%
#Проверяем:
df['purpose_category'].value_counts()
# Out:
# операции с недвижимостью    10763
# операции с автомобилем       4284
# получение образования        3995
# проведение свадьбы           2310
# Name: purpose_category, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21352 entries, 0 to 21351
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   children               21352 non-null  int64
#  1   days_employed          21352 non-null  float64
#  2   dob_years              21352 non-null  int64
#  3   education_id           21352 non-null  int64
#  4   family_status_id       21352 non-null  int64
#  5   gender                 21352 non-null  object
#  6   income_type            21352 non-null  object
#  7   debt                   21352 non-null  int64
#  8   total_income           21352 non-null  int64
#  9   purpose                21352 non-null  object
#  10  total_income_category  21351 non-null  object
#  11  purpose_category       21352 non-null  object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Основные цели кредита определены правильно! 👍
# </div>

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Между количеством детей у заемщика и возвратом кредита в срок есть зависимость.

# %%
#Посмотрим, какой % кредитов не выплачивался в вовремя:
df.loc[df['debt'] == 1]['debt'].count()/len(df)*100
# Out:
# 8.116335706257024

# %%
#Посмотрим, какой % кредитов не выплачивался в вовремя, при наличии детей, но вне зависимости от их количества,по 
#отношению ко всем заемщикам:
df.loc[(df['debt'] == 1) & (df['children'] != 0)]['debt'].count()/len(df)*100
# Out:
# 3.1612963656800304

# %%
#Посмотрим, какой % кредитов не выплачивался в вовремя, при наличии детей, но вне зависимости от их количества,по 
#отношению к заемщикам с детьми:
df.loc[(df['debt'] == 1) & (df['children'] != 0)]['debt'].count() / df.loc[df['children'] != 0]['debt'].count()*100
# Out:
# 9.207475105715455

# %% [markdown]
# Построим сводную таблицу задолженность / дети:

# %%
pivot_table_check_children = df.pivot_table(index=['debt'], columns='children', values='gender', aggfunc='count')

# %%
pivot_table_check_children
# Out:
# children            0           1           2          3         4        5
# debt
# 0        12963.000000 4397.000000 1912.000000 301.000000 37.000000 9.000000
# 1         1058.000000  442.000000  202.000000  27.000000  4.000000      NaN

# %%
children0 = pivot_table_check_children[0][1] / (pivot_table_check_children[0][0] + pivot_table_check_children[0][1])
children1 = pivot_table_check_children[1][1] / (pivot_table_check_children[1][0] + pivot_table_check_children[1][1])
children2 = pivot_table_check_children[2][1] / (pivot_table_check_children[2][0] + pivot_table_check_children[2][1])
children3 = pivot_table_check_children[3][1] / (pivot_table_check_children[3][0] + pivot_table_check_children[3][1])
children4 = pivot_table_check_children[4][1] / (pivot_table_check_children[4][0] + pivot_table_check_children[4][1])

print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков без детей".format(children0*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков с 1 ребенком".format(children1*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков с 2 детьми".format(children2*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков с 3 детьми".format(children3*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков с 4 детьми".format(children4*100))
# Out:
# 7.55% кредитов не выплачивалось вовремя, среди заемщиков без детей
# 9.13% кредитов не выплачивалось вовремя, среди заемщиков с 1 ребенком
# 9.56% кредитов не выплачивалось вовремя, среди заемщиков с 2 детьми
# 8.23% кредитов не выплачивалось вовремя, среди заемщиков с 3 детьми
# 9.76% кредитов не выплачивалось вовремя, среди заемщиков с 4 детьми

# %% [markdown]
# Можно сделать вывод, что заемщики без детей реже просрочивают выплаты по кредиту.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Верно!
# </div>

# %% [markdown]
# ### Между семейным положением заемщика и возвратом кредита в срок есть зависимость.

# %%
# Сводная таблица задолженность / семейный статус:
pivot_table_check_family = df.pivot_table(index=['debt'], columns='family_status_id' , values='gender', aggfunc='count')

# %%
pivot_table_check_family
# Out:
# family_status_id      0     1    2     3     4
# debt
# 0                 11363  3743  892  1100  2521
# 1                   927   386   62    85   273

# %%
#что нашел:
pivot_table_check_family.apply(lambda x:100 * x / float(x.sum()))
# Out:
# family_status_id         0         1         2         3         4
# debt
# 0                92.457282 90.651489 93.501048 92.827004 90.229062
# 1                 7.542718  9.348511  6.498952  7.172996  9.770938

# %%
# Проверим, что метод выше не врет:
family_id_0 = pivot_table_check_family[0][1] / (pivot_table_check_family[0][0] + pivot_table_check_family[0][1])
family_id_1 = pivot_table_check_family[1][1] / (pivot_table_check_family[1][0] + pivot_table_check_family[1][1])
family_id_2 = pivot_table_check_family[2][1] / (pivot_table_check_family[2][0] + pivot_table_check_family[2][1])
family_id_3 = pivot_table_check_family[3][1] / (pivot_table_check_family[3][0] + pivot_table_check_family[3][1])
family_id_4 = pivot_table_check_family[4][1] / (pivot_table_check_family[4][0] + pivot_table_check_family[4][1])

print("{0:.2f}% кредитов не выплачивалось вовремя, среди женатых/замужних заемщиков".format(family_id_0*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков в гражданском браке ".format(family_id_1*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков вдовцов/вдов".format(family_id_2*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди заемщиков в разводе ".format(family_id_3*100))
print("{0:.2f}% кредитов не выплачивалось вовремя, среди не женатых/не замужних заемщиков ".format(family_id_4*100))
# Out:
# 7.54% кредитов не выплачивалось вовремя, среди женатых/замужних заемщиков
# 9.35% кредитов не выплачивалось вовремя, среди заемщиков в гражданском браке
# 6.50% кредитов не выплачивалось вовремя, среди заемщиков вдовцов/вдов
# 7.17% кредитов не выплачивалось вовремя, среди заемщиков в разводе
# 9.77% кредитов не выплачивалось вовремя, среди не женатых/не замужних заемщиков

# %% [markdown]
# Можно сделать вывод, что заемщики, имевшие штамп в паспорте(вдовцы, разведенные, женатые)  реже просрочивают кредит, в сравнении, с заемщиками, которые не были отягощены узами брака(гражданский брак, не женатые).

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Тут всё правильно
# </div>

# %% [markdown]
# ### Между уровнем дохода заемщика и возвратом кредита в срок есть зависимость.

# %%
# Сводная таблица задолженность / категория дохода:
pivot_table_check_salary = df.pivot_table(index=['debt'], columns='total_income_category', values='gender', aggfunc='count')

# %%
pivot_table_check_salary.apply(lambda x:100 * x / float(x.sum()))
# Out:
# total_income_category         A         B         C         D         E
# debt
# 0                     92.000000 92.919824 91.512985 93.965517 90.909091
# 1                      8.000000  7.080176  8.487015  6.034483  9.090909

# %% [markdown]
# Зависимости между уровнем дохода и возвратом кредита в срок нет.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен! Идём дальше)
# </div>

# %% [markdown]
# ### Разные цели кредита влияют на его возврат в срок.

# %%
# Сводная таблица задолженность / цели кредита:
pivot_table_check_goal = df.pivot_table(index=['debt'], columns='purpose_category', values='gender', aggfunc='count')

# %%
pivot_table_check_goal.apply(lambda x:100 * x / float(x.sum()))
# Out:
# purpose_category  операции с автомобилем  операции с недвижимостью  \
# debt
# 0                              90.662932                 92.762241
# 1                               9.337068                  7.237759
#
# purpose_category  получение образования  проведение свадьбы
# debt
# 0                             90.738423           92.034632
# 1                              9.261577            7.965368

# %% [markdown]
# Заемщики, с целью кредита операции с недвижимостью и проведение свадьбы чаще возвращают кредит в срок, чем заемщики, цель кредита которых операции с автомобилем и получение образования.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Абсолютно верно!
# </div>

# %% [markdown]
# ## Итоги исследования

# %% [markdown]
# Мы проверили обработали данные на пропуски и аномалии, подготовили их к анализу и проверили 4 гипотезы:
# 1. Заемщики без детей реже просрочивают выплаты по кредиту, между количеством детей и количеством просроченных кредитов есть зависимость.
#
# 2. Между семейным положением и выплатой кредитов в срок тоже есть зависимость, причем, интересен тот факт, что заемщики, у которых был или есть официальный брак реже просрочивают выплаты.
#
# 3. Между уровнем дохода и выплатами кредита в срок нет прямой зависимости. Возможно на результат проверки данной гипотезы повлияли пропуски в `total_income`, или способ, которым мы заполняли пропуски.
#
# 4. Цель  кредита влияет на его возврат в срок, так, мы можем утверждать, что заемщики, с целями кредита `операции с недвижимостью` и `проведение свадьбы` относятся более ответственно к погашению кредита в срок.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Общий вывод верный 👍
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v1:</b>
# <br>Я бы мог принять твою работу с первого раза, но хочу дать тебе возможность задать мне вопросы) Если вопросов нет, то я с радостью приму проект)
# </div>
